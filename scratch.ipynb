# %%
from generate_distributions import plot
from scipy import stats


# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plot('poisson')

# %%
stats.poisson(mu=2).rvs(1000)
# Out:
# array([3, 3, 2, 2, 2, 2, 0, 4, 2, 1, 2, 2, 2, 0, 3, 3, 1, 2, 4, 3, 4, 3,
#        0, 3, 1, 1, 0, 3, 1, 5, 2, 1, 0, 5, 3, 3, 4, 3, 0, 1, 3, 2, 4, 1,
#        2, 1, 2, 2, 0, 2, 2, 3, 2, 1, 1, 5, 1, 2, 2, 1, 1, 2, 4, 1, 1, 2,
#        1, 1, 2, 1, 2, 2, 3, 5, 2, 1, 1, 1, 3, 2, 4, 2, 4, 0, 3, 1, 4, 4,
#        2, 1, 2, 3, 0, 0, 5, 2, 4, 5, 2, 3, 1, 0, 1, 2, 1, 5, 1, 1, 4, 3,
#        2, 0, 0, 1, 2, 2, 0, 4, 3, 0, 2, 2, 4, 3, 1, 2, 6, 4, 1, 0, 0, 1,
#        3, 1, 1, 2, 0, 0, 0, 1, 1, 3, 1, 1, 4, 2, 2, 4, 3, 2, 3, 1, 2, 1,
#        0, 2, 1, 1, 5, 3, 3, 1, 1, 5, 3, 1, 2, 3, 1, 0, 1, 0, 2, 2, 5, 2,
#        3, 1, 4, 1, 2, 2, 3, 1, 1, 4, 1, 2, 2, 2, 2, 3, 3, 3, 3, 1, 2, 1,
#        2, 2, 3, 3, 0, 1, 2, 2, 3, 3, 0, 2, 1, 6, 4, 2, 1, 1, 0, 2, 1, 3,
#        3, 0, 0, 0, 3, 3, 1, 1, 3, 1, 3, 1, 3, 0, 3, 3, 0, 2, 2, 4, 3, 2,
#        2, 3, 4, 3, 0, 1, 3, 2, 5, 3, 4, 3, 1, 2, 1, 5, 4, 2, 2, 3, 4, 2,
#        1, 6, 1, 5, 3, 1, 2, 2, 0, 1, 2, 1, 1, 2, 1, 1, 0, 2, 3, 1, 3, 0,
# ...
